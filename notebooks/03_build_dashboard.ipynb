# %% [markdown]
# # Build Interactive MEA Dashboard
#
# Create the dashboard HTML shell from an existing processed cache. Notebook 01 must be run first so dashboard data files exist.

# %%
from pathlib import Path

from acute_slice_mea.dashboard import write_dashboard_from_cache

cache_dir = Path("../data/processed/brain_slice_well004_cache")
dashboard_html = write_dashboard_from_cache(cache_dir, title="Brain Slice MEA Dashboard")
dashboard_dir = dashboard_html.parent

print(f"Dashboard HTML: {dashboard_html}")
print("\nStart a local server from a terminal:")
print(f"cd {dashboard_dir.resolve()}")
print("python -m http.server 8000")
print("\nThen open:")
print("http://localhost:8000/index.html")
