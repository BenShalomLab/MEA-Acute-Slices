# %% [markdown]
# # Acute Slice MEA Analysis Template
#
# Use this notebook as a starting point for acute-slice multi-electrode array analysis.

# %% [markdown]
# ## Import

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Load Data
#
# Place raw MEA files in `data/raw/`. Keep large recordings out of git.

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ## Analyze

# %% [markdown]
# ## Visualize

# %% [markdown]
# ## Export
#
# Generated figures and PDFs are ignored by git.
